# %% [markdown]
# Graph:
# 1. what are the applications of graph model or Data structure?
# - When the emphasis is on Pair-wise relationship.
# - Lets take social media applications:
#     - Typical application is when a user-follower/ user-friends relationsip in application like
#         facebook, X, instagram.
#     - Course schedule.
#     - Accounts Merge
# 2. Why cant you use existing data structures or why other datastructures fail to
#     support these use cases?
# - The requirement here is to store the relationships between people, and a dependency graph
#  in the case of course schedule.
#
# 3. Why cant you use Trees? or why should you think these as graph problems?
# - The structure of Trees, is that the information flows from root to leaves(Top to bottom).
# - But, we need a datastructure which could handle the bidirectional flow of information in the case
# of social media apps.
# - Course schedule:
#     - Why should you think this as a directed graph?
#         - Because there is a dependency associated with the nodes/courses.
#     - Why can't you think this as a Tree problem?
#         - Bcz there can be scenarios where cross and back edges are possible in the course dependencies and trees doesnt support these properties.
# 4. Why is Accounts Merge a Graph Problem?
# - Some observations about the problem:
#     1. The goal is to merge the accounts based on a common email.
#     2.
# - Using hahsmap to solve this?
#     -
#
# 4. What are the structural properties of Tree and Graph?
# Tree:
# - In a tree, there should be no cross edges or back edges.
# - Information flow is pure Top down.
# - In cases like B-tree indexes, there can exist scenarios where the information/accessing information/exectuion happens from bottom to top, while splitting the parent nodes, but strictly speaking accessing the B+ tree is Top-down.
#
# Graph:
# - Information is bidirectional in un-directed graphs.
# - There can exists cross or back edges.
#
# 5. Structural and execution properties of a undirected and directed graphs:
#
#
#
# 2. What is the difference between Tree and a Graph?
#
# - Structural properties:
# - A graph can be represented as a BFS TREE.
# - A graph can be represented as a DFS TREE.
#
# 3. How does the information flow in Graphs vs Trees?
#
# What is the time complexity of the graphs:
# 1. So,  I think , this depends on the ways you represent/store the graph.
# 2. But in general it is number of the edges in the graph, to traverse the whole graph.
# O(E)
# Adjacency lists :
# 1. Most frequent way of representing the graphs.
